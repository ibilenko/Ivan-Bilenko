# %% [markdown]
# # Только вырезки

# %% [markdown]
# # Циан

# %%
import requests
from bs4 import BeautifulSoup
import random
import re
from random import choice
import io
import random
import time
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
import pandas as pd
from fake_useragent import UserAgent

# %%
url_main = 'https://www.cian.ru/agentstva/'
proxies = {
    "https": 'https://wpfpz84d0k:vmy51wr6ju@dc4.ibaldr.ru:8150'
    }

headers = {":authority:",
"www.cian.ru",
":method:",
"GET",
":path:",
"/company/12696435/",
":scheme:",
"https",
"accept:",
"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
"accept-encoding:",
"gzip, deflate, br",
"accept-language:",
"ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7",
"cookie:",
"__cfduid=d6f0268399c1f7e72cb8442c11ed7fab91614710746; _CIAN_GK=8d6ef09c-ee10-4ef0-b994-14938dd989e7; login_mro_popup=meow; fingerprint=673d8a7edb0d6894fd80e4622199e9b0; sopr_utm=%7B%22utm_source%22%3A+%22direct%22%2C+%22utm_medium%22%3A+%22None%22%7D; sopr_session=7f6e18d629ea469b; _gcl_au=1.1.2130282647.1614710751; uxfb_usertype=searcher; uxs_uid=83269f80-7b87-11eb-a826-5be32dc84af2; uxs_mig=1; tmr_lvid=96147512421efb9886b779b7de2ebe80; tmr_lvidTS=1614710751627; _ga=GA1.2.59510449.1614710752; _gid=GA1.2.8877859.1614710752; _fbp=fb.1.1614710751891.1238832914; afUserId=2344a0db-3d94-4634-9a42-50312ab4b7ec-p; rrpvid=583162467499751; rcuid=603e882fc5e32e000176d816; __cf_bm=fdb77f6022dab69e1a430d1cf5ac10c036e458ae-1614711204-1800-AUt8MbJeeBf7QINqWIg7GMXP8mfSgbOtpDPmJo3JZaUpo8oBeGbpWvVGvwkkTSQBJV8tv+9U5LVWs3YhJJlzKK8=; cto_bundle=6PbqJV8wYkxxd2I1enF6JTJGSkFQVFpnQnFacTFqbGlZc0tEZUtnN1pmYXZ1ZG1RRkY2Z0JxYVR2ciUyRnJZNmw1cWNVNEt0bjNKRE9nMTEyZWhnWkhnU251SGFiNXpnQVglMkJVcjBLTU55RThBaW9VaUZ5cFZvakgwMEk0YklBUU5OVElQOXFLM0VxVHpjSm5PYllqYVZzNGptbE8xR0ElM0QlM0Q; tmr_detect=0%7C1614711211356; tmr_reqNum=39",
"referer:",
"https://www.cian.ru/agentstva/",
"sec-fetch-dest:",
"document",
"sec-fetch-mode:",
"navigate",
"sec-fetch-site:",
"same-origin",
"sec-fetch-user:",
"?1",
"upgrade-insecure-requests:",
"1",
"user-agent:",
"Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Mobile Safari/537.36"}

r1 = requests.get(url_main,
                    proxies = proxies,
                    verify = False)
soup = BeautifulSoup(r1.text,'lxml')
url = []
for p in soup.find_all('a',attrs = {"class":"js-offers-button s-button"}):
    url.append(p.get('href'))

# %%
name = []
Spec = []
phone1 = []
phone2 = []
phone3 = []
adress = []
site = []
suggestion = []
j = 501
while j<=3463:
    if divmod(j,50)[1] == 0:
        df = pd.DataFrame({'name':name,'spec':Spec,'phone1':phone1,'phone2':phone2,'phone3':phone3,'adress':adress,'site':site,'suggestion':suggestion})
        #for k in range(len(df['name'])):
            #df['name'][k] = df['name'][k].replace('\n                ','').replace(' - агентство недвижимости, контакты, объекты агентства недвижимости\n            ','')
        df.to_excel(r"E:\Питончик\агентсва{}.xlsx".format(j))       
    ua = UserAgent().random
    proxies = {
    "https": 'https://wpfpz84d0k:vmy51wr6ju@dc4.ibaldr.ru:8150'
    }
    headers = {'authority': 'www.cian.ru',
    'method': 'GET',
    'path': '{}'.format(url['url'][j]),
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': '__cfduid=d372525ecf2288a649e6d00e749a832cc1615147116; _CIAN_GK=d84c42ba-38db-4155-999d-618ff2bf0b60; __cf_bm=ae6b09cfd7ffb28c4f908e467993dac44a9c83e0-1615147116-1800-AbboMJAtrq+9xhV2sIbmzb4xlUt2dC3/16Sd8PXvNseADGHlamQvVtvM7ud+aC+W8J/KdMG0ph1mLR75iBXyZhI=; sopr_utm=%7B%22utm_source%22%3A+%22yandex%22%2C+%22utm_medium%22%3A+%22organic%22%7D; sopr_session=99e8b86d1a794f31; _gcl_au=1.1.184902562.1615147117; yaref=1; uxfb_usertype=searcher; rrpvid=329893259431149; tmr_lvid=1341743f2f94c7b80c5e8694f17a6859; tmr_lvidTS=1615147117712; rcuid=6045306ed633e500010a15ae; _ga=GA1.2.707809281.1615147118; _gid=GA1.2.1485698520.1615147118; uxs_uid=81ce09b0-7f7f-11eb-b26a-c11f191dd799; uxs_mig=1; _ym_uid=1615147118912924934; _ym_d=1615147118; _ym_visorc=b; _ym_isad=2; _fbp=fb.1.1615147118736.1669615173; afUserId=91f2c403-deec-4b61-8bd6-a68396bc32b3-p; _dc_gtm_UA-30374201-1=1; tmr_detect=0%7C1615147221296; tmr_reqNum=12',
    'referer': 'https://www.cian.ru/agentstva/',
    'sec-ch-ua': '"Google Chrome";v="89", "Chromium";v="89", ";Not A Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': ua}
    url_m = 'https://www.cian.ru'+url['url'][j]
    time.sleep(random.uniform(1,2))
    try:
        r1 = requests.get(url_m,
                        proxies = proxies,
                          headers = headers,
                        verify = False,
                         timeout = 10)
        print('r1 = {}'.format(r1.status_code))
    except:
        print('Уже на первом этапе меня выбросило:(, перерыв')
        time.sleep(random.uniform(20,30))
        continue
    soup = BeautifulSoup(r1.text,'lxml')
    for p in soup.find_all('title'):
        name.append(p)
    if soup.find_all('div',attrs = {"class":"profile__speciality"}):    
        for p in soup.find_all('div',attrs = {"class":"profile__speciality"}):
            Spec.append(p)   
    else:
        Spec.append('-')
        print('Нет специализации')
        
    i = 0
    #if soup.find_all('div',attrs = {"class":"profile__hidden-phone"}):
    for p in soup.find_all('div',attrs = {"class":"profile__hidden-phone"}):
        if len(soup.find_all('div',attrs = {"class":"profile__hidden-phone"})) == 1:
            phone1.append(p)
            print('1 телефон')
            #print('phone1, i=1')
            phone2.append('-')
            phone3.append('-')
        if len(soup.find_all('div',attrs = {"class":"profile__hidden-phone"})) == 2:
            if i == 0:
                phone1.append(p)
                #print('phone1, i=2')
                i+=1
            else:    
                phone2.append(p)
                phone3.append('-')
        if len(soup.find_all('div',attrs = {"class":"profile__hidden-phone"})) == 3:  
            if i == 0:
                phone1.append(p.text)
                #print('phone1, i=3')
                i+=1
            else:
                if i ==1:
                    phone2.append(p)
                    i+=1
                else:
                    phone3.append(p)
    if len(soup.find_all('div',attrs = {"class":"profile__hidden-phone"})) not in [1,2,3]:
        phone1.append('-')
        print('Нет телефона')
        phone2.append('-')
        phone3.append('-')

    #else:
        
    i = 0
    for p in soup.find_all('div',attrs = {"class":"profile__field-value"}):
        if len(soup.find_all('div',attrs = {"class":"profile__field-value"})) == 1:
            if re.findall('.ru',str(p.text)) or re.findall('.com',str(p.text)):
                site.append(p)
                adress.append('-')
            else:
                site.append('-')
                adress.append(p)
        if len(soup.find_all('div',attrs = {"class":"profile__field-value"})) == 2:        
            if i == 0:
                site.append(p)
                i+=1
            else:
                adress.append(p)
                i-=1
    if len(soup.find_all('div',attrs = {"class":"profile__field-value"})) not in [1,2]: 
        site.append('-')
        adress.append('-')
        print('Нет адреса и сайта')
    summa = 0
    for p in soup.find_all('a',attrs = {"class":"js-ga-event profile__all-offers profile__link agents__link"}):
        summa += int(re.findall('\d+',p.text)[0]) 
    suggestion.append(summa)
    print(j)
    j+=1

# %% [markdown]
# # list org

# %%
j = 0
#%%
import requests
from bs4 import BeautifulSoup
import random
from random import choice
import io

url_main = 'https://www.list-org.com/search'
i = 16
while i < 804:
    time.sleep(random.uniform(0.2,0.5))
    ogrn = df['ogrn'][i]
    seartype = ['inn','ogrn']
    ua = UserAgent().random
    head_search = {
    'authority': 'www.list-org.com'
    ,'method': 'GET'
    ,'path' : '/search'
    ,'scheme': 'https'
    ,'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'
    ,'accept-encoding': 'gzip, deflate, br'
    ,'accept-language': 'en-US,en;q=0.9'
    # ,'cookie': '_ga=GA1.2.1642710245.1607244265; _gid=GA1.2.1749957142.1607244265; __gads=ID=a6dd4237bbba024d-22b0f6bd54b9007a:T=1607244284:RT=1607244284:S=ALNI_Max-13fKu7m5jNd52WsRANvd9_fNw; _gat_gtag_UA_114579997_1=1'
    ,'sec-fetch-dest': 'document'
    ,'sec-fetch-mode': 'navigate'
    ,'sec-fetch-site': 'same-origin'
    ,'sec-fetch-user': '?1'
    ,'upgrade-insecure-requests': '1'
    ,'user-agent': ua
    #,'referer': 'https://www.google.com/search?'+ogrn
    }
    head_parse = {
    'authority': 'www.list-org.com'
    ,'method': 'GET'
    ,'path' : '/search?type=all&val={}'.format(ogrn)
    ,'scheme': 'https'
    ,'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'
    ,'accept-encoding': 'gzip, deflate, br'
    ,'accept-language': 'en-US,en;q=0.9'
    # ,'cookie': '_ga=GA1.2.1642710245.1607244265; _gid=GA1.2.1749957142.1607244265; __gads=ID=a6dd4237bbba024d-22b0f6bd54b9007a:T=1607244284:RT=1607244284:S=ALNI_Max-13fKu7m5jNd52WsRANvd9_fNw; _gat_gtag_UA_114579997_1=1'
    ,'sec-fetch-dest': 'document'
    ,'sec-fetch-mode': 'navigate'
    ,'sec-fetch-site': 'same-origin'
    ,'sec-fetch-user': '?1'
    ,'upgrade-insecure-requests': '1'
    ,'user-agent': ua
    ,'referer': 'https://www.list-org.com/search?val={}&type=all'.format(ogrn)
    }
    proxies = {
    "https": 'https://wpfpz84d0k:vmy51wr6ju@dc4.ibaldr.ru:8150'
    }
    #print('wpfpz84d0k')
    Parametrs = {'type': seartype[1], 'val': ogrn}
    try:
        r1 = requests.get(url_main,
                          params = Parametrs,
                          proxies = proxies,
                          verify = False,
                          headers = head_search )
        print('r1 = {}'.format(r1.status_code))
    except:
        print('Уже на первом этапе меня выбросило:(, перерыв')
        time.sleep(random.uniform(20,30))
        continue
    if r1.status_code == 200:
        if 'Найдено 0 организаций :' in r1.text:
            print('Нет данных по ИНН')
            my_file = open(r"E:\Питончик\{}ul.txt".format(i+1), "w+",encoding='utf-8-sig')
            my_file.write('Нет данных по ИНН')
            my_file.close()
            #files.download("{}.txt".format(i+1))
            i=i+1
        else:
            try:
                nurl = BeautifulSoup(r1.content, 'html.parser').find_all('p')[1].find('a').get('href')
            except:
                print('Мне дали капчу, пойду посплю 2 мин , хех')
                time.sleep(random.uniform(120,121))
                continue
            try:
                time.sleep(random.uniform(0.2,0.5))
                r2 = requests.get('https://www.list-org.com' + nurl,
                              proxies = proxies,
                              verify = False,
                              headers = head_parse,
                              timeout = 10)
                print('r2 = 200')
            except:
                print('Не подключился на втором этапе, пошёл занаво')
                continue
            if r2.status_code == 200:
                print('Успешно, кладем в txt')
                soup = BeautifulSoup(r2.text)
                if 'Вы слишком часто обращались к сайту' in r2.text:
                    continue
                else: 
                    my_file = open(r"E:\Питончик\{}ul.txt".format(i+1), "w+",encoding='utf-8-sig')
                    my_file.write(str(soup))
                    my_file.close()
                    #files.download("{}.txt".format(i+1))
                    i=i+1
            else:
                my_file = open(r"E:\Питончик\{}ul.txt".format(i+1), "w+",encoding='utf-8-sig')
                my_file.write(str(r2.status_code))
                my_file.close()
                #files.download("{}.txt".format(i+1))
                print('ошибка на 2 этапе')
                

    else:
        continue

# %%
for i in range(1,805):
    if i ==16:
        i+=1
    inn = []
    phone = []
    result = []
    f2 = open(r"E:\Питончик\{}ul.txt".format(i),'r',encoding='utf-8-sig')
    text = f2.read()
    b_text = BeautifulSoup(text)
    if re.findall('8\s.\d{3}.\s\d{3}-\d{2}-\d{2}',str(b_text)):
        phone.append(re.findall('8\s.\d{3}.\s\d{3}-\d{2}-\d{2}',str(b_text)))
    if re.findall('8\s.\d{5}.\s\d{1}-\d{2}-\d{2}',str(b_text)):
        phone.append(re.findall('8\s.\d{5}.\s\d{1}-\d{2}-\d{2}',str(b_text)))
    for row in b_text.find_all('td'):
        res = re.findall('>\d{1,3}[.]\d{1,3}<',str(row))
        if res:
            result.append(res[0].split('>')[1].split('<')[0])
    for row in b_text.find_all('td'):
        res = re.findall('>\d{1,3}[.]\d{1,3}[.]\d{1,3}<',str(row))
        if res:
            result.append(res[0].split('>')[1].split('<')[0])
    for row in b_text.find_all('td'):
        res = re.findall('>\d{10,12}\s[/]',str(row))
        if res:
            inn.append(res[0].split('>')[1].split(' /')[0])
    series = {'inn':inn,'phone':phone,'okved':result}
    df = df.append(series,ignore_index=True)

# %% [markdown]
# # Rusprofile

# %%
req = requests.get(URL,headers = headers)
soup = BeautifulSoup(req.text, 'lxml')
headers1 = []
for i in range(500,501):
    user_agent = random.choice(ua)
    headers1.append({'authority': 'www.rusprofile.ru',
    'method': 'GET',
    'path': '/codes/493200{}'.format(i),
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
                     'cache-control': 'max-age=0',
    'cookie': '_ym_uid=1607873269729262622; _ym_d=1607873269; subscription__price=group_6; _ym_isad=2; _ga=GA1.2.380405434.1607873270; _gid=GA1.2.703638411.1607873270; __gads=ID=3318f5a4042c6fb5-220307cc64b900a3:T=1607873274:RT=1607873274:S=ALNI_MZF6lnEp4gAyDM9qNR3fVJozy6j9w; okved_all=yes; _ym_visorc_39561835=w; _ym_visorc_26812653=b; screen_for_ad=mobile',           
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': user_agent,})
    prox_l = {'http' : 'http://' + choice(proxy_list)}
    req = requests.get(URL_m[i-1],headers = headers1[i-500], proxies = prox_l)
    if req.status_code == 200:
        soup = BeautifulSoup(req.text, 'lxml')
        name = []
        info = []
        for p in soup.find_all("dd"):
            info.append(p.text)
        for j in range(len(info)):
            if re.findall('^\d{10}$',info[j]) and not re.findall('^\d{13}$',info[j]):
                inn.append(''.join(re.findall('^\d{10}$',info[j])))
        time.sleep(random.uniform(1,4))
    else:
        i = i-1
        time.sleep(random.uniform(1,4))
